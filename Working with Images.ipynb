# %%
# %pip install pillow
from PIL import Image
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Image.open("example.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
eg=Image.open("example.jpg")

# %%
eg.size
# Out:
# (1993, 1257)

# %%
halfway=1993/2
x1=halfway-200
x2=halfway+200

y1=1257/2+200
y2=1257

# %%
eg.crop((x1,y1,x2,y2))
# Out:
# <PIL.Image.Image image mode=RGB size=400x429>

# %%
img=eg.crop((x1,y1,x2,y2))

# %%
eg.paste(im=img,box=(530,0))

# %%
eg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %% [markdown]
# Displaying colors images

# %%
red=Image.open("red_color.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
red.putalpha(120)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
blue=Image.open("blue_color.png")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200>

# %%
blue.paste(im=red, box=(0, 0), mask=red)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200>

# %% [markdown]
# Exercise

# %%
word=Image.open("word_matrix.png")

# %%
word.size
# Out:
# (1015, 559)

# %%
word
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>

# %%
m=Image.open("mask.png")

# %%
m
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
m=m.resize((1015,559))

# %%
m.size
# Out:
# (1015, 559)

# %%
m.putalpha(200)

# %%
m
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
word.paste(m,(0,0),m)

# %%
word
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>
